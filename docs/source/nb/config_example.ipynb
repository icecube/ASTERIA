# %% [markdown]
# # Example Configuration

# %%
from asteria.simulation import Simulation
from snewpy.neutrino import Flavor

import matplotlib.pyplot as plt
import os

# %%
base_path = os.environ['ASTERIA']
sim = Simulation(config=os.path.join(base_path, 'data/config/example.ini'))
sim.run()

fig, ax = plt.subplots(1, figsize = (6,7))
for flavor in sim.flavors:
    ax.plot(sim.time, sim.avg_dom_signal(flavor), label=flavor.name)
ax.legend()
ax.set(xlabel=r't-t$_{bounce}$ [s]', ylabel='Signal per DOM', xlim=(-0.025, 0.65));
# Out:
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]
# /home/sgris/Code/venvs/Asteria/lib/python3.7/site-packages/astropy-3.2.1-py3.7-linux-x86_64.egg/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# Starting NU_E simulation...       DONE
# Starting NU_E_BAR simulation...   DONE
# Starting NU_X simulation...       DONE
# Starting NU_X_BAR simulation...   DONE
