# %%
from asteria.simulation import Simulation
import astropy.units as u

model = {'name': 'Nakazato_2013',
         'param':{
             'progenitor_mass': 13*u.Msun,
             'revival_time': 300 * u.ms,
             'metallicity': 0.004,
             'eos': 'shen'}
         }
sim = Simulation(model=model,
                 distance=10 * u.kpc, 
                 Emin=0*u.MeV, Emax=100*u.MeV, dE=1*u.MeV,
                 tmin=-1*u.s, tmax=1*u.s, dt=1*u.ms)
sim.run()

import matplotlib.pyplot as plt
for flavor in sim.flavors:
    plt.plot(sim.time, sim.E_per_V[flavor], label=flavor.name)
plt.legend()
ax = plt.gca()
ax.set(xlabel=r't-t$_{bounce}$ [s]', ylabel='Energy Deposition [Mev m$^{-3}$])', xlim=(-0.15, 0.75));
# Out:
# /Users/thomasahrens/opt/anaconda3/lib/python3.8/site-packages/astropy/table/row.py:76: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   return self.as_void() == other
# Beginning NU_E simulation...       Completed
# Beginning NU_E_BAR simulation...   Completed
# Beginning NU_X simulation...       Completed
# Beginning NU_X_BAR simulation...   Completed

# %%
from asteria.simulation import Simulation
import astropy.units as u

sim = Simulation(config='config_tester.ini')
sim.run()

import matplotlib.pyplot as plt
for flavor in sim.flavors:
    plt.plot(sim.time, sim.E_per_V[flavor], label=flavor.name)
plt.legend()
ax = plt.gca()
ax.set(xlabel=r't-t$_{bounce}$ [s]', ylabel='Energy Deposition [Mev m$^{-3}$])', xlim=(-0.15, 0.75));
# Out:
# ---------------------------------------------------------------------------
# MissingSectionHeaderError                 Traceback (most recent call last)
# <ipython-input-2-fce6b95f12a2> in <module>
#       2 import astropy.units as u
#       3
# ----> 4 sim = Simulation(config='config_tester.ini')
#       5 sim.run()
#       6
#
# ~/Desktop/IceCube/ASTERIA/python/asteria/simulation.py in __init__(self, config, model, distance, flavors, hierarchy, interactions, mixing_scheme, mixing_angle, E, Emin, Emax, dE, t, tmin, tmax, dt)
#      69             with open(config) as f:
#      70                 configuration = configparser.ConfigParser()
# ---> 71                 configuration.read_file(config)
#      72                 default = configuration['DEFAULT']
#      73                 model = configuration['MODEL']
#
# ~/opt/anaconda3/lib/python3.8/configparser.py in read_file(self, f, source)
#     716             except AttributeError:
#     717                 source = '<???>'
# --> 718         self._read(f, source)
#     719
#     720     def read_string(self, string, source='<string>'):
#
# ~/opt/anaconda3/lib/python3.8/configparser.py in _read(self, fp, fpname)
#    1080                 # no section header in the file?
#    1081                 elif cursect is None:
# -> 1082                     raise MissingSectionHeaderError(fpname, lineno, line)
#    1083                 # an option line?
#    1084                 else:
#
# MissingSectionHeaderError: File contains no section headers.
# file: '<???>', line: 1
# 'c'
